# %% [markdown]
# # Dataset Features Extraction

# %% [markdown]
# Notebook By: **Nicolas Escobar Cruz**,
# Github:<https://github.com/nicolaxs69>,
# Email:<nicoescobar69@gmail.com>

# %% [markdown]
# First, import the libraries we will using along the code. **scipy** for the extraction of statistics analysis of data, **matplotlib** for visualization and plotting data, and **numpy** for numeric fuctions operations.

# %%
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Read the file which contains the dataset and load into an array, parsing this from a String into an integer value. (Be sure your dataset is in the same root or directory that your coding file in order to be load succesfully)

# %%
file = 'Conv_S-1_#3.txt' # C:\Users\Nicolas\PycharmProjects\untitled\Dataset\Corriendo\Conv_s-1_#3.txt (using absolute route)
list = [line.rstrip('\n') for line in open(file)]
data = [int(x) for x in list] # Parse String to int
print (data)
# Out:
# [500, 505, 501, 496, 500, 505, 500, 496, 500, 505, 500, 496, 501, 506, 502, 497, 502, 508, 502, 498, 502, 508, 503, 499, 504, 509, 505, 499, 505, 509, 505, 500, 505, 510, 505, 499, 505, 510, 505, 500, 505, 510, 505, 500, 505, 509, 505, 500, 504, 509, 504, 499, 504, 509, 504, 499, 504, 508, 503, 499, 503, 508, 503, 499, 503, 508, 503, 498, 503, 508, 504, 499, 504, 509, 505, 504, 514, 525, 526, 528, 531, 532, 518, 502, 497, 493, 478, 458, 453, 457, 457, 470, 495, 523, 542, 558, 570, 573, 560, 544, 534, 527, 506, 479, 455, 440, 432, 435, 457, 487, 515, 547, 577, 587, 573, 551, 540, 532, 510, 479, 453, 440, 444, 452, 477, 507, 532, 556, 579, 579, 556, 523, 492, 463, 445, 451, 476, 515, 553, 588, 616, 617, 592, 563, 546, 519, 462, 408, 412, 433, 447, 480, 512, 547, 578, 603, 617, 614, 583, 555, 534, 504, 459, 426, 435, 453, 464, 487, 519, 558, 585, 599, 593, 572, 541, 515, 492, 476, 463, 458, 476, 503, 527, 553, 587, 601, 582, 535, 499, 476, 456, 464, 493, 527, 558, 588, 613, 611, 585, 563, 547, 521, 476, 437, 440, 452, 475, 506, 533, 562, 584, 597, 595, 583, 557, 529, 494, 462, 446, 455, 486, 529, 551, 569, 591, 594, 565, 520, 489, 472, 475, 499, 531, 558, 571, 585, 596, 593, 577, 555, 524, 494, 462, 455, 479, 516, 539, 555, 580, 599, 589, 571, 558, 543, 512, 477, 469, 480, 494, 517, 541, 558, 565, 567, 562, 549, 523, 497, 493, 501, 509, 519, 539, 560, 574, 579, 580, 574, 558, 535, 513, 485, 463, 464, 487, 518, 538, 549, 563, 572, 562, 548, 539, 521, 497, 482, 491, 511, 524, 529, 536, 537, 532, 530, 532, 519, 495, 479, 484, 505, 520, 537, 563, 581, 578, 570, 566, 561, 539, 509, 487, 472, 456, 452, 472, 497, 515, 529, 550, 568, 572, 570, 576, 576, 562, 544, 532, 513, 489, 467, 459, 458, 457, 465, 487, 512, 529, 542, 559, 570, 570, 569, 567, 560, 540, 518, 505, 490, 460, 438, 435, 444, 457, 473, 498, 528, 546, 559, 574, 585, 580, 568, 558, 542, 518, 496, 484, 475, 460, 451, 448, 454, 460, 472, 499, 530, 553, 574, 590, 593, 577, 556, 540, 526, 503, 479, 467, 462, 448, 440, 454, 475, 496, 525, 563, 593, 593, 575, 552, 527, 500, 485, 488, 502, 512, 524, 540, 557, 560, 553, 541, 522, 495, 473, 469, 473, 474, 481, 502, 527, 544, 557, 562, 547, 515, 485, 478, 483, 493, 511, 534, 561, 579, 588, 592, 579, 553, 527, 507, 472, 431, 420, 425, 448, 470, 483, 513, 551, 583, 602, 610, 602, 575, 549, 529, 504, 467, 435, 436, 436, 431, 441, 463, 487, 504, 530, 567, 595, 603, 594, 585, 572, 544, 513, 494, 477, 458, 450, 450, 455, 459, 465, 487, 517, 541, 566, 590, 603, 588, 565, 551, 539, 518, 494, 470, 457, 445, 430, 445, 471, 492, 513, 542, 568, 576, 573, 569, 561, 546, 528, 519, 508, 482, 457, 456, 459, 465, 479, 502, 524, 534, 545, 557, 562, 555, 542, 540, 536, 521, 502, 485, 468, 454, 452, 468, 488, 502, 519, 544, 564, 565, 560, 558, 556, 544, 527, 513, 500, 476, 460, 458, 466, 473, 484, 507, 532, 544, 551, 559, 565, 557, 547, 543, 537, 521, 507, 504, 493, 476, 460, 459, 463, 465, 470, 484, 499, 502, 508, 524, 539, 543, 544, 549, 549, 538, 526, 521, 517, 507, 494, 495, 496, 489, 484, 490, 497, 493, 489, 495, 505, 509, 515, 532, 547, 547, 540, 538, 532, 517, 504, 503, 502, 495, 487, 488, 494, 491, 488, 499, 513, 517, 519, 524, 523, 510, 500, 500, 500, 486, 469, 466, 468, 465, 466, 480, 494, 499, 503, 515, 525, 529, 536, 553, 568, 567, 555, 540, 522, 495, 464, 442, 436, 428, 427, 448, 470, 484, 504, 533, 556, 562, 568, 583, 596, 591, 576, 554, 524, 485, 450, 429, 415, 391, 383, 389, 415, 440, 469, 513, 556, 573, 574, 577, 584, 584, 578, 574, 563, 541, 513, 488, 465, 445, 432, 428, 422, 407, 404, 423, 457, 487, 516, 558, 587, 591, 587, 588, 588, 576, 556, 542, 520, 482, 455, 453, 454, 454, 464, 486, 504, 513, 519, 531, 541, 540, 537, 543, 548, 543, 536, 536, 535, 523, 508, 504, 501, 491, 480, 481, 484, 480, 478, 486, 494, 495, 495, 503, 513, 512, 511, 519, 525, 521, 515, 518, 519, 512, 505, 509, 513, 508, 503, 507, 512, 508, 505, 510, 516, 513, 508, 513, 517, 510, 505, 511, 517, 513, 509, 511, 514, 509, 506, 510, 513, 506, 499, 501, 504, 498, 492, ...

# %% [markdown]
# Next is extract statistical information from the data in order to get features that describe the behavior of the data. In this case a seizure

# %%
maximo = np.max(data)
minimo = np.min(data)
media  = np.mean(data)
varianza = np.var(data)

a = "Maximo:",maximo
b = "Minimo:",minimo
c = "Media:", media
d = "Varianza:",varianza

print ("Maximo:",maximo)
print ("Minimo:",minimo)
print ("Media:", media)
print("Varianza:",varianza)
# Out:
# Maximo: 769
# Minimo: 324
# Media: 553.660240291
# Varianza: 2731.89115736

# %% [markdown]
# Plot the data and the information:

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.set_title(file)
ax1.set_xlabel('Number of Samples')
ax1.set_ylabel('Acelometer analog value')
ax1.plot(data, c='b', label=a+b+c+d)

leg = ax1.legend()

plt.show()

# %% [markdown]
# ## Using the preprocessing API from scikit-learn

# %% [markdown]
# The sklearn.preprocessing package provides several common utility functions and transformer classes to change raw feature vectors into a representation that is more suitable for the downstream estimators.This is an alternative option to calculte the **mean** an **varianze**.

# %%
from sklearn import preprocessing
import numpy as np

# %% [markdown]
# Reshape your data either X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.This is necesary to work with preprocessing API.

# %%
data_fit = np.array(data).reshape((len(data), -1))
print(data_fit)
# Out:
# [[500]
#  [505]
#  [501]
#  ...,
#  [595]
#  [600]
#  [595]]

# %%
scaler = preprocessing.StandardScaler().fit(data_fit)
print('Media Scalar API:',scaler.mean_)
print('Scala API:', scaler.scale_)
print('Transform API:', scaler.transform(data_fit))
# Out:
# Media Scalar API: [ 553.66024029]
# Scala API: [ 52.26749618]
# Transform API: [[-1.02664647]
#  [-0.93098472]
#  [-1.00751412]
#  ...,
#  [ 0.79092673]
#  [ 0.88658847]
#  [ 0.79092673]]
# C:\Users\Nicolas\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %% [markdown]
# ## Fourier transform coefficients

# %% [markdown]
# Using the Scipy library to extract the fourier transform, the spectrum of the transform is determined and the fourier coefficients are determined.

# %%
from scipy.fftpack import fft, rfft, irfft
import matplotlib.pyplot as plt

# %%
file = 'Conv_S-1_#3.txt' 
list = [line.rstrip('\n') for line in open(file)]
data = [int(x) for x in list] # Parse String to int

# %% [markdown]
# Fast Fourier Transform:

# %%
fft(data)
print (fft(data))
# Out:
# [ 9907750.00000000     +0.j           -78459.60271484-324711.41255406j
#   -199728.05423187+130206.38240242j ...,  -130576.77308947+115970.66681559j
#   -199728.05423187-130206.38240242j   -78459.60271484+324711.41255406j]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("Trasnformada de Fourier")
ax1.set_xlabel('Numero de muestras')
ax1.set_ylabel('Muestras Sensor')
ax1.plot(fft(data), c='b', label='Trasnformada de Fourier')
leg = ax1.legend()
plt.show()
# Out:
# C:\Users\Nicolas\Anaconda3\lib\site-packages\numpy\core\numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Using the rfft to calculte the Fourier transform coefficients:

# %%
yr = rfft(data)
print (yr)
# Out:
# [  9.90775000e+06  -7.84596027e+04  -3.24711413e+05 ...,   4.46763059e+00
#    1.62282073e+02  -1.42453959e+02]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_title("Coeficientes de Fourier")
ax1.set_xlabel('Numero de muestras')
ax1.set_ylabel('Muestras Sensor')
ax1.plot(yr, c='b', label='Coeficientes de Fourier')
leg = ax1.legend()
plt.show()

# %% [markdown]
# # # That's all for now...
